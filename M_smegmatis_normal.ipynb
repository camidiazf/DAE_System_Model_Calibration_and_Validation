# %%
from DAE_analysis_package.RUN_functions import RUN_COMBOS       # Main function to run all combinations of parameter sets and bounds
from M_smegmatis_normal.DAE_Systems_Simulations import simulate_model   # Function to simulate the DAE system
from M_smegmatis_normal.System_data import system_data                  # System data including initial conditions, parameters, and experimental data

system_data['parameters'] = {
    'k_C': 0.05, 
    'k_O' : 0.001, 
    'k_d': 0.0001, 
    'YX_CO2': 0.35, 
    'YX_O2' : 1.352, 
    'YX_C': 0.4840,
    'Xmax': 1.1,  
    'mu_max': 0.1335, ## 0.3
    't_lag': 20,
    'm_C':     0.008,   # glycerol maintenance coeff [g gly / gX / h]  ← the decoupler
    'f_Nrec':  0.5,     # fraction of decay-N recycled to medium (ammonification)
    'pH_opt':  7.5,     # pH optimum for growth  (was implicitly pH_UL)
    'pH_w':    5.5,     # pH inhibition width; ≈ (pH_UL − pH_LL)/2
    'Y_CO2_m': 0.05,     # CO2 produced per unit maintenance glycerol (stoich.)
    'Y_O2_m':  1.0,     # O2 consumed per unit maintenance glycerol (stoich.),
    'rho_N_max': 0.5,   # max specific N UPTAKE rate          [g N / gX / h]
    'k_Nup':    0.0001,   # half-saturation for N uptake         [g N / L]
    'q_min':    0.0001,   # subsistence N quota (growth floor)   [g N / gX],
    'q_max':     0.11,   # max N quota (storage ceiling)        [g N / gX]


}

parameters_and_bounds = {
    'k_C': [0.049, 0.051],
    'k_O' : [0.0001, 0.00011],
    # 'k_d': [0.0001, 0.001],
    'YX_CO2': [0.4, 0.41],
    # 'YX_O2' : [1.3, 1.4],
    'YX_C': [0.6, 0.61],
    'Xmax': [1.1, 1.11],
    'mu_max': [0.26, 0.261],
    't_lag': [20, 20.1],
    # 'm_C':     [0.005, 0.015],   # glycerol maintenance coeff [g gly / gX / h]  ← the decoupler
    # 'f_Nrec':  [0.4, 0.6],     # fraction of decay-N recycled to medium (ammonification)
    'pH_opt':  [6.8, 6.81],     # pH optimum for growth  (was implicitly pH_UL)
    # 'pH_w':    [5.0, 6.0],     # pH inhibition width; ≈ (pH_UL − pH_LL)/2
    # 'Y_CO2_m': [0.04, 0.06],     # CO2 produced per unit maintenance glycerol (stoich.)
    # 'Y_O2_m':  [0.9, 1.1],     # O2 consumed per unit maintenance glycerol (stoich.),
    # 'k_Nup':    [0.01, 0.03],   # half-saturation for N uptake         [g N / L]
    # 'q_min':    [0.0001, 0.001],   # subsistence N quota (growth floor)   [g N / gX],
    # 'q_max':     [0.1, 0.12],   # max N quota (storage ceiling)        [g N / gX]
} 

df_M_smegmatis = RUN_COMBOS(
                    system_data=system_data,                        # Model system data
                    simulate_model=simulate_model,                  # Function to simulate your DAE system
                    folder_model='M_smegmatis_normal',                  # Name of the folder containing your model files
                    folder_results='FINAL_METRICS',                    # Folder to save results
                    solve_calibrate='calibrate',                     # Choose to 'solve' the model, 'calibrate' parameters
                    iterations=3,                                   # Number of iterations for each combination
                    parameters_and_bounds=parameters_and_bounds,    # Parameters to calibrate and their bounds
                    min_k = 8,                                    # Minimum number of parameters to calibrate simultaneously (optional)
                    # max_k = 1,                                    # Maximum number of parameters to calibrate simultaneously (optional
                )
# Out:
#            Original Parameters
# k_C                     0.0500
# k_O                     0.0010
# k_d                     0.0001
# YX_CO2                  0.3500
# YX_O2                   1.3520
# YX_C                    0.4840
# Xmax                    1.1000
# mu_max                  0.1335
# t_lag                  20.0000
# m_C                     0.0080
# f_Nrec                  0.5000
# pH_opt                  7.5000
# pH_w                    5.5000
# Y_CO2_m                 0.0500
# Y_O2_m                  1.0000
# rho_N_max               0.5000
# k_Nup                   0.0001
# q_min                   0.0001
# q_max                   0.1100
#
#
# >>> Running original model validation...
# ------------------------------
# >>> Running model VALIDATION
# ------------------------------
#   Variable      RMSE      MAPE      NRMSE  AIC  BIC
# 0        X  0.161397  0.164525  10.907798  NaN  NaN
# 1        C  0.326659  0.122398   5.385677  NaN  NaN
# 2        N  0.029809  0.234997   2.479403  NaN  NaN
# 3       pH  0.129555  0.161943   1.413361  NaN  NaN
# 4    Model  0.193925  0.027862   5.046560
#
# Durbin-Watson statistic: 1.3964476722543142
#  > Positive autocorrelation detected in residuals -> Residual may not be independent.
#
# Anderson-Darling test statistic: 2.4322460150286602
#
# Critical values and significance levels (Null hypothesis = H0):
#       Significance level 15.0%: Critical value 0.55 -> H0 rejected (non-normality)
#       Significance level 10.0%: Critical value 0.619 -> H0 rejected (non-normality)
#       Significance level 5.0%: Critical value 0.737 -> H0 rejected (non-normality)
#       Significance level 2.5%: Critical value 0.856 -> H0 rejected (non-normality)
#       Significance level 1.0%: Critical value 1.015 -> H0 rejected (non-normality)
# c:\Users\camil\OneDrive\DAE Model Analysis\M_smegmatis_DAE_2026\DAE_analysis_package\Validation_functions.py:145: FutureWarning: As of SciPy 1.17, users must choose a p-value calculation method by providing the `method` parameter. `method='interpolate'` interpolates the p-value from pre-calculated tables; `method` may also be an instance of `MonteCarloMethod` to approximate the p-value via Monte Carlo simulation. When `method` is specified, the result object will include a `pvalue` attribute and not attributes `critical_value`, `significance_level`, or `fit_result`. Beginning in 1.19.0, these other attributes will no longer be available, and a p-value will always be computed according to one of the available `method` options.
#   result = stats.anderson(residuals)
#
# ---------------------------------------------------------------------------------
# ---------------------- MODEL COMPARISON TO VALIDATION DATA ----------------------
# ---------------------------------------------------------------------------------
#
#
# ------------------------------------
# >>> Running model PARAMETER ANALYSIS
# ------------------------------------
#
# Column norms (parameter sensitivities):
#   k_C                   4.996e-01   OK
#   k_O                   0.000e+00   VERY SMALL → may be unidentifiable
#   k_d                   0.000e+00   VERY SMALL → may be unidentifiable
#   YX_CO2                0.000e+00   VERY SMALL → may be unidentifiable
#   YX_O2                 0.000e+00   VERY SMALL → may be unidentifiable
#   YX_C                  0.000e+00   VERY SMALL → may be unidentifiable
#   Xmax                  0.000e+00   VERY SMALL → may be unidentifiable
#   mu_max                0.000e+00   VERY SMALL → may be unidentifiable
#   t_lag                 0.000e+00   VERY SMALL → may be unidentifiable
#   m_C                   0.000e+00   VERY SMALL → may be unidentifiable
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 1 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.996e-01   OK
#   k_O                   2.831e+02   OK
#   k_d                   0.000e+00   VERY SMALL → may be unidentifiable
#   YX_CO2                0.000e+00   VERY SMALL → may be unidentifiable
#   YX_O2                 0.000e+00   VERY SMALL → may be unidentifiable
#   YX_C                  0.000e+00   VERY SMALL → may be unidentifiable
#   Xmax                  0.000e+00   VERY SMALL → may be unidentifiable
#   mu_max                0.000e+00   VERY SMALL → may be unidentifiable
#   t_lag                 0.000e+00   VERY SMALL → may be unidentifiable
#   m_C                   0.000e+00   VERY SMALL → may be unidentifiable
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 2 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.996e-01   OK
#   k_O                   2.831e+02   OK
#   k_d                   2.959e+01   OK
#   YX_CO2                0.000e+00   VERY SMALL → may be unidentifiable
#   YX_O2                 0.000e+00   VERY SMALL → may be unidentifiable
#   YX_C                  0.000e+00   VERY SMALL → may be unidentifiable
#   Xmax                  0.000e+00   VERY SMALL → may be unidentifiable
#   mu_max                0.000e+00   VERY SMALL → may be unidentifiable
#   t_lag                 0.000e+00   VERY SMALL → may be unidentifiable
#   m_C                   0.000e+00   VERY SMALL → may be unidentifiable
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 3 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.996e-01   OK
#   k_O                   2.831e+02   OK
#   k_d                   2.959e+01   OK
#   YX_CO2                1.874e+00   OK
#   YX_O2                 0.000e+00   VERY SMALL → may be unidentifiable
#   YX_C                  0.000e+00   VERY SMALL → may be unidentifiable
#   Xmax                  0.000e+00   VERY SMALL → may be unidentifiable
#   mu_max                0.000e+00   VERY SMALL → may be unidentifiable
#   t_lag                 0.000e+00   VERY SMALL → may be unidentifiable
#   m_C                   0.000e+00   VERY SMALL → may be unidentifiable
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 4 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.996e-01   OK
#   k_O                   2.831e+02   OK
#   k_d                   2.959e+01   OK
#   YX_CO2                1.874e+00   OK
#   YX_O2                 4.155e-03   OK
#   YX_C                  0.000e+00   VERY SMALL → may be unidentifiable
#   Xmax                  0.000e+00   VERY SMALL → may be unidentifiable
#   mu_max                0.000e+00   VERY SMALL → may be unidentifiable
#   t_lag                 0.000e+00   VERY SMALL → may be unidentifiable
#   m_C                   0.000e+00   VERY SMALL → may be unidentifiable
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 5 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.996e-01   OK
#   k_O                   2.831e+02   OK
#   k_d                   2.959e+01   OK
#   YX_CO2                1.874e+00   OK
#   YX_O2                 4.155e-03   OK
#   YX_C                  4.005e+00   OK
#   Xmax                  0.000e+00   VERY SMALL → may be unidentifiable
#   mu_max                0.000e+00   VERY SMALL → may be unidentifiable
#   t_lag                 0.000e+00   VERY SMALL → may be unidentifiable
#   m_C                   0.000e+00   VERY SMALL → may be unidentifiable
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 6 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4
/ 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.996e-01   OK
#   k_O                   2.831e+02   OK
#   k_d                   2.959e+01   OK
#   YX_CO2                1.874e+00   OK
#   YX_O2                 4.155e-03   OK
#   YX_C                  4.005e+00   OK
#   Xmax                  1.691e+00   OK
#   mu_max                1.715e+01   OK
#   t_lag                 7.094e-02   OK
#   m_C                   2.661e+01   OK
#   f_Nrec                2.958e-04   OK
#   pH_opt                8.466e-02   OK
#   pH_w                  9.311e-03   OK
#   Y_CO2_m               5.289e-02   OK
#   Y_O2_m                1.607e-03   OK
#   rho_N_max             2.628e-03   OK
#   k_Nup                 1.440e-03   OK
#   q_min                 2.101e+01   OK
#   q_max                 1.521e+00   OK
#
# Rank(G): 19 / 19: G is full rank → STRUCTURALLY IDENTIFIABLE
#
# Highly correlated parameter pairs:
#
# MODEL ID: [1, 1]
#
# >>> Calibrating parameters ['k_C', 'k_O', 'YX_CO2', 'YX_C', 'Xmax', 'mu_max', 't_lag', 'pH_opt'], for 3 iterations.
#     lb = [0.049, 0.0001, 0.4, 0.6, 1.1, 0.26, 20.0, 6.8]
#     ub = [0.051, 0.00011, 0.41, 0.61, 1.11, 0.261, 20.1, 6.81]
#
# >>> Calibration iteration 1 for parameters ['k_C', 'k_O', 'YX_CO2', 'YX_C', 'Xmax', 'mu_max', 't_lag', 'pH_opt']
# >>> Running PSO calibration iteration 1...
# Optimization Results:
#      Best Solutions:  [4.96746426e-02 1.00211331e-04 4.02076194e-01 6.05488713e-01
#  1.10573151e+00 2.60577317e-01 2.00750677e+01 6.80918416e+00]
#      Minimum Error:  1000000.0
#      Optimization Time: 1.19 s
#
# New Parameters after PSO Calibration:
#   Parameter        Original / Base        New
# 0             k_C           0.0500   0.049675
# 1             k_O           0.0010   0.000100
# 2          YX_CO2           0.3500   0.402076
# 3            YX_C           0.4840   0.605489
# 4            Xmax           1.1000   1.105732
# 5          mu_max           0.1335   0.260577
# 6           t_lag          20.0000  20.075068
# 7          pH_opt           7.5000   6.809184
#
# ------------------------------
# >>> Running model VALIDATION
# ------------------------------
#   Variable      RMSE      MAPE     NRMSE         AIC        BIC
# 0        X  0.082757  0.084361  7.149199         NaN        NaN
# 1        C  0.220668  0.082683  4.460588         NaN        NaN
# 2        N  0.025083  0.197737  2.130828         NaN        NaN
# 3       pH  0.085172  0.106466  1.036222         NaN        NaN
# 4    Model  0.125923  0.018092  3.694209 -147.766682  29.526892
#
# Durbin-Watson statistic: 2.1320976111682106
#  > No autocorrelation detected in residuals -> Residual may be independent.
#
# Anderson-Darling test statistic: 1.5369447894250001
#
# Critical values and significance levels (Null hypothesis = H0):
#       Significance level 15.0%: Critical value 0.55 -> H0 rejected (non-normality)
#       Significance level 10.0%: Critical value 0.619 -> H0 rejected (non-normality)
#       Significance level 5.0%: Critical value 0.737 -> H0 rejected (non-normality)
#       Significance level 2.5%: Critical value 0.856 -> H0 rejected (non-normality)
#       Significance level 1.0%: Critical value 1.015 -> H0 rejected (non-normality)
# c:\Users\camil\OneDrive\DAE Model Analysis\M_smegmatis_DAE_2026\DAE_analysis_package\Validation_functions.py:145: FutureWarning: As of SciPy 1.17, users must choose a p-value calculation method by providing the `method` parameter. `method='interpolate'` interpolates the p-value from pre-calculated tables; `method` may also be an instance of `MonteCarloMethod` to approximate the p-value via Monte Carlo simulation. When `method` is specified, the result object will include a `pvalue` attribute and not attributes `critical_value`, `significance_level`, or `fit_result`. Beginning in 1.19.0, these other attributes will no longer be available, and a p-value will always be computed according to one of the available `method` options.
#   result = stats.anderson(residuals)
#
# ---------------------------------------------------------------------------------
# ---------------------- MODEL COMPARISON TO VALIDATION DATA ----------------------
# ---------------------------------------------------------------------------------
#
#
# ------------------------------------
# >>> Running model PARAMETER ANALYSIS
# ------------------------------------
#
# Column norms (parameter sensitivities):
#   k_C                   4.981e-01   OK
#   k_O                   0.000e+00   VERY SMALL → may be unidentifiable
#   k_d                   0.000e+00   VERY SMALL → may be unidentifiable
#   YX_CO2                0.000e+00   VERY SMALL → may be unidentifiable
#   YX_O2                 0.000e+00   VERY SMALL → may be unidentifiable
#   YX_C                  0.000e+00   VERY SMALL → may be unidentifiable
#   Xmax                  0.000e+00   VERY SMALL → may be unidentifiable
#   mu_max                0.000e+00   VERY SMALL → may be unidentifiable
#   t_lag                 0.000e+00   VERY SMALL → may be unidentifiable
#   m_C                   0.000e+00   VERY SMALL → may be unidentifiable
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 1 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.981e-01   OK
#   k_O                   3.156e+02   OK
#   k_d                   0.000e+00   VERY SMALL → may be unidentifiable
#   YX_CO2                0.000e+00   VERY SMALL → may be unidentifiable
#   YX_O2                 0.000e+00   VERY SMALL → may be unidentifiable
#   YX_C                  0.000e+00   VERY SMALL → may be unidentifiable
#   Xmax                  0.000e+00   VERY SMALL → may be unidentifiable
#   mu_max                0.000e+00   VERY SMALL → may be unidentifiable
#   t_lag                 0.000e+00   VERY SMALL → may be unidentifiable
#   m_C                   0.000e+00   VERY SMALL → may be unidentifiable
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 2 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.981e-01   OK
#   k_O                   3.156e+02   OK
#   k_d                   4.401e+01   OK
#   YX_CO2                0.000e+00   VERY SMALL → may be unidentifiable
#   YX_O2                 0.000e+00   VERY SMALL → may be unidentifiable
#   YX_C                  0.000e+00   VERY SMALL → may be unidentifiable
#   Xmax                  0.000e+00   VERY SMALL → may be unidentifiable
#   mu_max                0.000e+00   VERY SMALL → may be unidentifiable
#   t_lag                 0.000e+00   VERY SMALL → may be unidentifiable
#   m_C                   0.000e+00   VERY SMALL → may be unidentifiable
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 3 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.981e-01   OK
#   k_O                   3.156e+02   OK
#   k_d                   4.401e+01   OK
#   YX_CO2                2.136e+00   OK
#   YX_O2                 0.000e+00   VERY SMALL → may be unidentifiable
#   YX_C                  0.000e+00   VERY SMALL → may be unidentifiable
#   Xmax                  0.000e+00   VERY SMALL → may be unidentifiable
#   mu_max                0.000e+00   VERY SMALL → may be unidentifiable
#   t_lag                 0.000e+00   VERY SMALL → may be unidentifiable
#   m_C                   0.000e+00   VERY SMALL → may be unidentifiable
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 4 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.981e-01   OK
#   k_O                   3.156e+02   OK
#   k_d                   4.401e+01   OK
#   YX_CO2                2.136e+00   OK
#   YX_O2                 8.805e-04   OK
#   YX_C                  0.000e+00   VERY SMALL → may be unidentifiable
#   Xmax                  0.000e+00   VERY SMALL → may be unidentifiable
#   mu_max                0.000e+00   VERY SMALL → may be unidentifiable
#   t_lag                 0.000e+00   VERY SMALL → may be unidentifiable
#   m_C                   0.000e+00   VERY SMALL → may be unidentifiable
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 5 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.981e-01   OK
#   k_O                   3.156e+02   OK
#   k_d                   4.401e+01   OK
#   YX_CO2                2.136e+00   OK
#   YX_O2                 8.805e-04   OK
#   YX_C                  4.660e+00   OK
#   Xmax                  0.000e+00   VERY SMALL → may be unidentifiable
#   mu_max                0.000e+00   VERY SMALL → may be unidentifiable
#   t_lag                 0.000e+00   VERY SMALL → may be unidentifiable
#   m_C                   0.000e+00   VERY SMALL → may be unidentifiable
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 6 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.981e-01   OK
#   k_O                   3.156e+02   OK
#   k_d                   4.401e+01   OK
#   YX_CO2                2.136e+00   OK
#   YX_O2                 8.805e-04   OK
#   YX_C                  4.660e+00   OK
#   Xmax                  3.461e+00   OK
#   mu_max                0.000e+00   VERY SMALL → may be unidentifiable
#   t_lag                 0.000e+00   VERY SMALL → may be unidentifiable
#   m_C                   0.000e+00   VERY SMALL → may be unidentifiable
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 7 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.981e-01   OK
#   k_O                   3.156e+02   OK
#   k_d                   4.401e+01   OK
#   YX_CO2                2.136e+00   OK
#   YX_O2                 8.805e-04   OK
#   YX_C                  4.660e+00   OK
#   Xmax                  3.461e+00   OK
#   mu_max                8.518e+00   OK
#   t_lag                 0.000e+00   VERY SMALL → may be unidentifiable
#   m_C                   0.000e+00   VERY SMALL → may be unidentifiable
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 8 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.981e-01   OK
#   k_O                   3.156e+02   OK
#   k_d                   4.401e+01   OK
#   YX_CO2                2.136e+00   OK
#   YX_O2                 8.805e-04   OK
#   YX_C                  4.660e+00   OK
#   Xmax                  3.461e+00   OK
#   mu_max                8.518e+00   OK
#   t_lag                 7.651e-02   OK
#   m_C                   0.000e+00   VERY SMALL → may be unidentifiable
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 9 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.981e-01   OK
#   k_O                   3.156e+02   OK
#   k_d                   4.401e+01   OK
#   YX_CO2                2.136e+00   OK
#   YX_O2                 8.805e-04   OK
#   YX_C                  4.660e+00   OK
#   Xmax                  3.461e+00   OK
#   mu_max                8.518e+00   OK
#   t_lag                 7.651e-02   OK
#   m_C                   3.852e+01   OK
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 10 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4
/ 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.981e-01   OK
#   k_O                   3.156e+02   OK
#   k_d                   4.401e+01   OK
#   YX_CO2                2.136e+00   OK
#   YX_O2                 8.805e-04   OK
#   YX_C                  4.660e+00   OK
#   Xmax                  3.461e+00   OK
#   mu_max                8.518e+00   OK
#   t_lag                 7.651e-02   OK
#   m_C                   3.852e+01   OK
#   f_Nrec                4.248e-04   OK
#   pH_opt                1.627e-02   OK
#   pH_w                  8.840e-04   OK
#   Y_CO2_m               5.905e-02   OK
#   Y_O2_m                2.148e-04   OK
#   rho_N_max             4.095e-03   OK
#   k_Nup                 2.292e-03   OK
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 17 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.981e-01   OK
#   k_O                   3.156e+02   OK
# ...
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 5 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.992e-01   OK
#   k_O                   3.160e+02   OK
#   k_d                   4.438e+01   OK
#   YX_CO2                2.145e+00   OK
#   YX_O2                 8.983e-04   OK
#   YX_C                  4.740e+00   OK
#   Xmax                  0.000e+00   VERY SMALL → may be unidentifiable
#   mu_max                0.000e+00   VERY SMALL → may be unidentifiable
#   t_lag                 0.000e+00   VERY SMALL → may be unidentifiable
#   m_C                   0.000e+00   VERY SMALL → may be unidentifiable
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 6 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.992e-01   OK
#   k_O                   3.160e+02   OK
#   k_d                   4.438e+01   OK
#   YX_CO2                2.145e+00   OK
#   YX_O2                 8.983e-04   OK
#   YX_C                  4.740e+00   OK
#   Xmax                  3.491e+00   OK
#   mu_max                0.000e+00   VERY SMALL → may be unidentifiable
#   t_lag                 0.000e+00   VERY SMALL → may be unidentifiable
#   m_C                   0.000e+00   VERY SMALL → may be unidentifiable
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 7 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.992e-01   OK
#   k_O                   3.160e+02   OK
#   k_d                   4.438e+01   OK
#   YX_CO2                2.145e+00   OK
#   YX_O2                 8.983e-04   OK
#   YX_C                  4.740e+00   OK
#   Xmax                  3.491e+00   OK
#   mu_max                8.562e+00   OK
#   t_lag                 0.000e+00   VERY SMALL → may be unidentifiable
#   m_C                   0.000e+00   VERY SMALL → may be unidentifiable
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 8 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.992e-01   OK
#   k_O                   3.160e+02   OK
#   k_d                   4.438e+01   OK
#   YX_CO2                2.145e+00   OK
#   YX_O2                 8.983e-04   OK
#   YX_C                  4.740e+00   OK
#   Xmax                  3.491e+00   OK
#   mu_max                8.562e+00   OK
#   t_lag                 7.685e-02   OK
#   m_C                   0.000e+00   VERY SMALL → may be unidentifiable
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 9 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.992e-01   OK
#   k_O                   3.160e+02   OK
#   k_d                   4.438e+01   OK
#   YX_CO2                2.145e+00   OK
#   YX_O2                 8.983e-04   OK
#   YX_C                  4.740e+00   OK
#   Xmax                  3.491e+00   OK
#   mu_max                8.562e+00   OK
#   t_lag                 7.685e-02   OK
#   m_C                   3.851e+01   OK
#   f_Nrec                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 10 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.992e-01   OK
#   k_O                   3.160e+02   OK
#   k_d                   4.438e+01   OK
#   YX_CO2                2.145e+00   OK
#   YX_O2                 8.983e-04   OK
#   YX_C                  4.740e+00   OK
#   Xmax                  3.491e+00   OK
#   mu_max                8.562e+00   OK
#   t_lag                 7.685e-02   OK
#   m_C                   3.851e+01   OK
#   f_Nrec                4.250e-04   OK
#   pH_opt                0.000e+00   VERY SMALL → may be unidentifiable
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 11 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.992e-01   OK
#   k_O                   3.160e+02   OK
#   k_d                   4.438e+01   OK
#   YX_CO2                2.145e+00   OK
#   YX_O2                 8.983e-04   OK
#   YX_C                  4.740e+00   OK
#   Xmax                  3.491e+00   OK
#   mu_max                8.562e+00   OK
#   t_lag                 7.685e-02   OK
#   m_C                   3.851e+01   OK
#   f_Nrec                4.250e-04   OK
#   pH_opt                1.704e-02   OK
#   pH_w                  0.000e+00   VERY SMALL → may be unidentifiable
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 12 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.992e-01   OK
#   k_O                   3.160e+02   OK
#   k_d                   4.438e+01   OK
#   YX_CO2                2.145e+00   OK
#   YX_O2                 8.983e-04   OK
#   YX_C                  4.740e+00   OK
#   Xmax                  3.491e+00   OK
#   mu_max                8.562e+00   OK
#   t_lag                 7.685e-02   OK
#   m_C                   3.851e+01   OK
#   f_Nrec                4.250e-04   OK
#   pH_opt                1.704e-02   OK
#   pH_w                  9.187e-04   OK
#   Y_CO2_m               0.000e+00   VERY SMALL → may be unidentifiable
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 13 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.992e-01   OK
#   k_O                   3.160e+02   OK
#   k_d                   4.438e+01   OK
#   YX_CO2                2.145e+00   OK
#   YX_O2                 8.983e-04   OK
#   YX_C                  4.740e+00   OK
#   Xmax                  3.491e+00   OK
#   mu_max                8.562e+00   OK
#   t_lag                 7.685e-02   OK
#   m_C                   3.851e+01   OK
#   f_Nrec                4.250e-04   OK
#   pH_opt                1.704e-02   OK
#   pH_w                  9.187e-04   OK
#   Y_CO2_m               5.903e-02   OK
#   Y_O2_m                0.000e+00   VERY SMALL → may be unidentifiable
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 14 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.992e-01   OK
#   k_O                   3.160e+02   OK
#   k_d                   4.438e+01   OK
#   YX_CO2                2.145e+00   OK
#   YX_O2                 8.983e-04   OK
#   YX_C                  4.740e+00   OK
#   Xmax                  3.491e+00   OK
#   mu_max                8.562e+00   OK
#   t_lag                 7.685e-02   OK
#   m_C                   3.851e+01   OK
#   f_Nrec                4.250e-04   OK
#   pH_opt                1.704e-02   OK
#   pH_w                  9.187e-04   OK
#   Y_CO2_m               5.903e-02   OK
#   Y_O2_m                9.032e-03   OK
#   rho_N_max             0.000e+00   VERY SMALL → may be unidentifiable
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 15 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.992e-01   OK
#   k_O                   3.160e+02   OK
#   k_d                   4.438e+01   OK
#   YX_CO2                2.145e+00   OK
#   YX_O2                 8.983e-04   OK
#   YX_C                  4.740e+00   OK
#   Xmax                  3.491e+00   OK
#   mu_max                8.562e+00   OK
#   t_lag                 7.685e-02   OK
#   m_C                   3.851e+01   OK
#   f_Nrec                4.250e-04   OK
#   pH_opt                1.704e-02   OK
#   pH_w                  9.187e-04   OK
#   Y_CO2_m               5.903e-02   OK
#   Y_O2_m                9.032e-03   OK
#   rho_N_max             9.897e-03   OK
#   k_Nup                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 16 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.992e-01   OK
#   k_O                   3.160e+02   OK
#   k_d                   4.438e+01   OK
#   YX_CO2                2.145e+00   OK
#   YX_O2                 8.983e-04   OK
#   YX_C                  4.740e+00   OK
#   Xmax                  3.491e+00   OK
#   mu_max                8.562e+00   OK
#   t_lag                 7.685e-02   OK
#   m_C                   3.851e+01   OK
#   f_Nrec                4.250e-04   OK
#   pH_opt                1.704e-02   OK
#   pH_w                  9.187e-04   OK
#   Y_CO2_m               5.903e-02   OK
#   Y_O2_m                9.032e-03   OK
#   rho_N_max             9.897e-03   OK
#   k_Nup                 2.285e-03   OK
#   q_min                 0.000e+00   VERY SMALL → may be unidentifiable
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 17 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.992e-01   OK
#   k_O                   3.160e+02   OK
#   k_d                   4.438e+01   OK
#   YX_CO2                2.145e+00   OK
#   YX_O2                 8.983e-04   OK
#   YX_C                  4.740e+00   OK
#   Xmax                  3.491e+00   OK
#   mu_max                8.562e+00   OK
#   t_lag                 7.685e-02   OK
#   m_C                   3.851e+01   OK
#   f_Nrec                4.250e-04   OK
#   pH_opt                1.704e-02   OK
#   pH_w                  9.187e-04   OK
#   Y_CO2_m               5.903e-02   OK
#   Y_O2_m                9.032e-03   OK
#   rho_N_max             9.897e-03   OK
#   k_Nup                 2.285e-03   OK
#   q_min                 2.057e+01   OK
#   q_max                 0.000e+00   VERY SMALL → may be unidentifiable
#
# Rank(G): 18 / 19: G is rank deficient → NOT STRUCTURALLY IDENTIFIABLE
#
# Column norms (parameter sensitivities):
#   k_C                   4.992e-01   OK
#   k_O                   3.160e+02   OK
#   k_d                   4.438e+01   OK
#   YX_CO2                2.145e+00   OK
#   YX_O2                 8.983e-04   OK
#   YX_C                  4.740e+00   OK
#   Xmax                  3.491e+00   OK
#   mu_max                8.562e+00   OK
#   t_lag                 7.685e-02   OK
#   m_C                   3.851e+01   OK
#   f_Nrec                4.250e-04   OK
#   pH_opt                1.704e-02   OK
#   pH_w                  9.187e-04   OK
#   Y_CO2_m               5.903e-02   OK
#   Y_O2_m                9.032e-03   OK
#   rho_N_max             9.897e-03   OK
#   k_Nup                 2.285e-03   OK
#   q_min                 2.057e+01   OK
#   q_max                 2.294e+00   OK
#
# Rank(G): 19 / 19: G is full rank → STRUCTURALLY IDENTIFIABLE
#
# Highly correlated parameter pairs:
#
# Computed t-values and confidence intervals:
# Parameter                 θ          SE     t-value   Signif?         CI low        CI high
# k_C                0.050550    0.516114        0.10        NO      -0.981677       1.082777
# k_O                0.000102    0.000429        0.24        NO      -0.000755       0.000959
# YX_CO2             0.401380    0.000225     1785.79       YES       0.400931       0.401830
# YX_C               0.600114    0.008483       70.74       YES       0.583147       0.617081
# Xmax               1.103129    0.001880      586.67       YES       1.099368       1.106889
# mu_max             0.260962    0.007188       36.31       YES       0.246587       0.275337
# t_lag             20.001166    1.360315       14.70       YES      17.280537      22.721796
# pH_opt             6.802921    1.341194        5.07       YES       4.120533       9.485309
